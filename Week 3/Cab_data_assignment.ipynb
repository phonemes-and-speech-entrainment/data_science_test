# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read main data file
df = pd.read_csv("Cab_Data.csv")

# %%
#check for structure
print(df.head())
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
#check for number of rows
print(len(df.index))
# Out:
# 359392

# %%
missing_values = df.isna()

# %%
print(missing_values)
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip
# 0               False         False
# 1               False         False
# 2               False         False
# 3               False         False
# 4               False         False
# ...               ...           ...
# 359387          False         False
# 359388          False         False
# 359389          False         False
# 359390          False         False
# 359391          False         False
#
# [359392 rows x 7 columns]

# %%
#fine NaN values by taking the total number
print(df.isna().sum())
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %% [markdown]
# There are no missing values for the Cab_Data file

# %%
#repeat for City, Customer ID and Transaction ID data files
df_city = pd.read_csv("City.csv")

# %%
print(df_city.head())
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
df_customer = pd.read_csv("Customer_ID.csv")

# %%
print(df_customer.head())
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
df_transaction = pd.read_csv("Transaction_ID.csv")

# %%
print(df_transaction.sample(20))
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 109987        10109998        43073         Card
# 197693        10197704         4247         Cash
# 253107        10253118        52207         Cash
# 108401        10108412        20322         Card
# 61022         10061033        18324         Card
# 131514        10131525        58505         Card
# 73260         10073271        59815         Cash
# 152190        10152201        58001         Cash
# 373051        10373062         2812         Card
# 10798         10010809        53903         Cash
# 236578        10236589        36337         Cash
# 64723         10064734        44292         Card
# 390789        10390800         1454         Card
# 236722        10236733        52188         Cash
# 218655        10218666         1382         Card
# 121944        10121955         7619         Card
# 266323        10266334         8647         Cash
# 339615        10339626          452         Card
# 13050         10013061        58358         Card
# 246579        10246590         3666         Card

# %%
print(df.sample(20))
# Out:
#         Transaction ID  Date of Travel     Company            City  \
# 298400        10366519           43336  Yellow Cab     NEW YORK NY
# 21149         10026817           42476  Yellow Cab     NEW YORK NY
# 235406        10287815           43100  Yellow Cab   WASHINGTON DC
# 62145         10077502           42623  Yellow Cab     NEW YORK NY
# 317824        10389997           43384  Yellow Cab  LOS ANGELES CA
# 23233         10029545           42483  Yellow Cab   WASHINGTON DC
# 229269        10280306           43092    Pink Cab     NEW YORK NY
# 110195        10134788           42742    Pink Cab  LOS ANGELES CA
# 86165         10106506           42693    Pink Cab      SEATTLE WA
# 344405        10421733           43439  Yellow Cab  LOS ANGELES CA
# 24206         10030703           42495  Yellow Cab  LOS ANGELES CA
# 171087        10210740           42963  Yellow Cab     NEW YORK NY
# 337298        10413329           43426  Yellow Cab      CHICAGO IL
# 214296        10262338           43065    Pink Cab    SAN DIEGO CA
# 60993         10076350           42629  Yellow Cab      ATLANTA GA
# 7360          10009488           42420  Yellow Cab       BOSTON MA
# 106076        10129992           42728  Yellow Cab     NEW YORK NY
# 288277        10354292           43304  Yellow Cab      CHICAGO IL
# 303680        10372883           43351  Yellow Cab     NEW YORK NY
# 278337        10341878           43272  Yellow Cab  LOS ANGELES CA
#
#         KM Travelled  Price Charged  Cost of Trip
# 298400          5.50         115.56       68.6400
# 21149          37.62        1052.00      541.7280
# 235406         23.46         416.38      315.3024
# 62145          22.89         581.73      280.1736
# 317824         33.66         550.71      468.5472
# 23233          23.94         483.10      324.6264
# 229269         20.23         394.17      202.3000
# 110195          7.76         129.08       85.3600
# 86165           9.54         132.26      112.5720
# 344405         27.04         425.99      389.3760
# 24206          37.37         882.45      457.4088
# 171087         41.80         886.00      516.6480
# 337298         18.36         275.58      237.9456
# 214296         10.80         149.45      110.1600
# 60993          34.10         533.73      474.6720
# 7360           28.71         524.82      354.8556
# 106076         34.92        1038.33      477.7056
# 288277         25.22         313.02      351.0624
# 303680         31.31         771.61      450.8640
# 278337         13.30         258.05      159.6000

# %%
print(df_customer.sample(20))
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 29007        10968  Female   20                3194
# 22358        15370    Male   53               22213
# 13742        19230  Female   19               19246
# 7858         58327  Female   29               15194
# 32705        39071    Male   65                9557
# 3685         43644    Male   21               21466
# 15099        43670  Female   36               11877
# 22649        40941    Male   24               16806
# 15422        41910  Female   39               21657
# 25117        29493    Male   56               18630
# 5967         43128    Male   28               15639
# 22496        53522  Female   35               18967
# 18464        18804    Male   34                4288
# 31030        55932    Male   64               22807
# 28150        46251    Male   23                4997
# 15023        45106    Male   32                5052
# 665           6353    Male   38               22207
# 7275         42445    Male   39                7878
# 31020        55052    Male   43               15145
# 27564        26741    Male   35               14326

# %%
print(df_city.sample(20))
# Out:
#                 City   Population      Users
# 1         CHICAGO IL   1,955,130    164,468
# 13         TUCSON AZ     631,442      5,712
# 19         BOSTON MA     248,968     80,021
# 7         PHOENIX AZ     943,999      6,133
# 6       SAN DIEGO CA     959,307     69,995
# 5      ORANGE COUNTY   1,030,185     12,994
# 8          DALLAS TX     942,908     22,157
# 15     SACRAMENTO CA     545,776      7,044
# 3           MIAMI FL   1,339,155     17,675
# 14  SAN FRANCISCO CA     629,591    213,609
# 10         DENVER CO     754,233     12,421
# 17     WASHINGTON DC     418,859    127,001
# 11         AUSTIN TX     698,371     14,978
# 4     SILICON VALLEY   1,177,609     27,247
# 2     LOS ANGELES CA   1,595,037    144,132
# 9         ATLANTA GA     814,885     24,701
# 16     PITTSBURGH PA     542,085      3,643
# 0        NEW YORK NY   8,405,837    302,149
# 12        SEATTLE WA     671,238     25,063
# 18      NASHVILLE TN     327,225      9,270

# %%
print(df_customer.isna().sum())
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
print(df_city.isna().sum())
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
print(df_transaction.isna().sum())
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %% [markdown]
# There are no missing values in the City, Customer_ID and Transaction_ID files

# %%
#check for duplicate values in each dataset
duplicate_df = df[df.duplicated()]

# %%
print(duplicate_df)
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Travel, Company, City, KM Travelled, Price Charged, Cost of Trip]
# Index: []

# %%
duplicate_df_city = df_city[df_city.duplicated()]

# %%
print(duplicate_df_city)
# Out:
# Empty DataFrame
# Columns: [City, Population, Users]
# Index: []

# %%
duplicate_df_customer = df_customer[df_customer.duplicated()]

# %%
print(duplicate_df_customer)
# Out:
# Empty DataFrame
# Columns: [Customer ID, Gender, Age, Income (USD/Month)]
# Index: []

# %%
duplicate_df_transaction = df_transaction[df_transaction.duplicated()]

# %%
print(duplicate_df_transaction)
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Payment_Mode]
# Index: []

# %% [markdown]
# There are no duplicate values in any of the data files

# %%
df_unique_transaction_id = df['Transaction ID'].unique()

# %%
print(len(df_unique_transaction_id))
# Out:
# 359392

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
#print unique values of each column, for each dataset, to better understand the data
for i in df.columns:
    print(i, '--', df[i].nunique())
# Out:
# Transaction ID -- 359392
# Date of Travel -- 1095
# Company -- 2
# City -- 19
# KM Travelled -- 874
# Price Charged -- 99176
# Cost of Trip -- 16291

# %%
for i in df_city.columns:
    print(i, '--', df_city[i].nunique())
# Out:
# City -- 20
# Population -- 20
# Users -- 20

# %%
for i in df_customer.columns:
    print(i, '--', df_customer[i].nunique())
# Out:
# Customer ID -- 49171
# Gender -- 2
# Age -- 48
# Income (USD/Month) -- 23341

# %%
for i in df_transaction.columns:
    print(i, '--', df_transaction[i].nunique())
# Out:
# Transaction ID -- 440098
# Customer ID -- 49171
# Payment_Mode -- 2

# %%
#check which cities correspond across the Cab_Data and City datasets
print(df_city)
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
print(df['City'].unique())
# Out:
# ['ATLANTA GA' 'AUSTIN TX' 'BOSTON MA' 'CHICAGO IL' 'DALLAS TX' 'DENVER CO'
#  'LOS ANGELES CA' 'MIAMI FL' 'NASHVILLE TN' 'NEW YORK NY' 'ORANGE COUNTY'
#  'PHOENIX AZ' 'PITTSBURGH PA' 'SACRAMENTO CA' 'SAN DIEGO CA' 'SEATTLE WA'
#  'SILICON VALLEY' 'TUCSON AZ' 'WASHINGTON DC']

# %%
print(df_city['City'].unique())
# Out:
# ['NEW YORK NY' 'CHICAGO IL' 'LOS ANGELES CA' 'MIAMI FL' 'SILICON VALLEY'
#  'ORANGE COUNTY' 'SAN DIEGO CA' 'PHOENIX AZ' 'DALLAS TX' 'ATLANTA GA'
#  'DENVER CO' 'AUSTIN TX' 'SEATTLE WA' 'TUCSON AZ' 'SAN FRANCISCO CA'
#  'SACRAMENTO CA' 'PITTSBURGH PA' 'WASHINGTON DC' 'NASHVILLE TN'
#  'BOSTON MA']

# %%
print(df.loc[df['City'].isin(['San Francisco'])])
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Travel, Company, City, KM Travelled, Price Charged, Cost of Trip]
# Index: []

# %% [markdown]
# San Francisco is missing from the large dataset

# %%
#check data types of each dataset
print(df.dtypes)
# Out:
# Transaction ID      int64
# Date of Travel      int64
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
print(df_city.dtypes)
# Out:
# City          object
# Population    object
# Users         object
# dtype: object

# %%
print(df_customer.dtypes)
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
print(df_transaction.dtypes)
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
#'Population' and 'Users' columns in the City dataset are given in the incorrect format, remove the comma and convert to int type
df_city['Population'] = df_city['Population'].str.replace(',','').astype('int')

# %%
df_city['Users'] = df_city['Users'].str.replace(',','').astype('int')

# %%
print(df_city.dtypes)
# Out:
# City          object
# Population     int64
# Users          int64
# dtype: object

# %%
df.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
#create copy of large dataset for master data
df2 = df

# %%
#add Earnings/Trip and Margin/Trip 
df2['Earnings/Trip'] = df2['Price Charged'] - df2['Cost of Trip']
df2['Margin/Trip'] = df2['Earnings/Trip']/df2['Price Charged']

# %%
df2.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip  Earnings/Trip    Margin/Trip
# count  359392.000000  359392.000000  359392.000000
# mean      286.190113     137.253198       0.271284
# std       157.993661     160.311840       0.185501
# min        19.000000    -220.060000      -0.693015
# 25%       151.200000      28.012000       0.138559
# 50%       282.480000      81.962000       0.264303
# 75%       413.683200     190.030000       0.416120
# max       691.200000    1463.966000       0.762026

# %%
#check for smallest age to create age groups
print(df_customer['Age'].min())
# Out:
# 18

# %%
#function which creates age groups
def ages(a):
    if a >= 65:
        return "Seniors >65 years old"
    elif a >= 45:
        return "45-65 years old"
    elif a >= 35:
        return "35-45 years old"
    elif a >= 25:
        return "25-35 years old"
    else:
        return "Young adults 18-25 years old"

df_customer['Age Category'] = df_customer['Age'].apply(ages)

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
#  4   Age Category        49171 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 1.9+ MB

# %%
df_customer.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
#these are to check numbers of customers per different income ranges
#print(df_customer.loc[(df_customer['Income (USD/Month)'] > 20000) & (df_customer['Income (USD/Month)'] < 23000)].count())
print(df_customer.loc[df_customer['Income (USD/Month)'] > 25000].count())
# Out:
# Customer ID           4516
# Gender                4516
# Age                   4516
# Income (USD/Month)    4516
# Age Category          4516
# dtype: int64

# %%
#plots to see if there is a connection between income and gender and income and age
sns.histplot(x = 'Income (USD/Month)', hue = 'Gender', bins = 100, data = df_customer)
plt.ylabel('Number of Trips')
plt.title('Relationship beteween Income and Number of Trips (Gender)')
plt.show()
sns.histplot(x = 'Income (USD/Month)', hue = 'Age Category', bins = 100, data = df_customer)
plt.ylabel('Number of Trips')
plt.title('Relationship beteween Income and Number of Trips (Age Category)')
plt.show()

# %%
sns.lmplot(x = 'Income (USD/Month)', y = 'Age', data = df_customer, fit_reg = True)
plt.title('Relationship between Income and Age')
plt.show()

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.4f}".format(x)})

# %%
age_income = np.corrcoef(df_customer['Income (USD/Month)'], df_customer['Age'])

# %%
print(age_income)
# Out:
# [[1.0000 0.0002]
#  [0.0002 1.0000]]

# %% [markdown]
# There is no relationship between income and age or income and gender, but the number of users who earn over 25,000 USD decreases dramatically for both companies.

# %%
#function to create income categories
def income(inc):
    if inc >= 25000:
        return ">25000"
    elif inc >= 15000:
        return "15000-25000"
    elif inc >= 5000:
        return "5000-15000"
    elif inc >= 3000:
        return "3000-5000"
    else:
        return "2000-3000"

df_customer['Income Category'] = df_customer['Income (USD/Month)'].apply(income)

# %%
df_customer.sample(10)
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)  \
# 41075        39428  Female   33                7093
# 9022         57155  Female   32               11001
# 36382        26809    Male   36               12608
# 39917        33906    Male   25               12671
# 35993         9924  Female   40               17654
# 5865         15667    Male   37               27071
# 42200        23157  Female   21                8515
# 11681        36778    Male   35               14151
# 8228          2962    Male   31               24006
# 24615        40131  Female   28                9870
#
#                        Age Category Income Category
# 41075               25-35 years old      5000-15000
# 9022                25-35 years old      5000-15000
# 36382               35-45 years old      5000-15000
# 39917               25-35 years old      5000-15000
# 35993               35-45 years old     15000-25000
# 5865                35-45 years old          >25000
# 42200  Young adults 18-25 years old      5000-15000
# 11681               35-45 years old      5000-15000
# 8228                25-35 years old     15000-25000
# 24615               25-35 years old      5000-15000

# %%
#change date format from Excel series to datetime, including information about the day of the week
import xlrd
import datetime as date

# %%
#do this by creating a separate variable
xl_date = df['Date of Travel']

# %%
xl_date.to_numpy()
# Out:
# array([42377, 42375, 42371, ..., 43105, 43105, 43102])

# %%
#this outputs the date and time for single elements (not array)
datetime_date = xlrd.xldate_as_datetime(xl_date[0], 0)

# %%
print(datetime_date)
# Out:
# 2016-01-08 00:00:00

# %%
#keep the date only
date_object = datetime_date.date()

# %%
print(type(date_object))
# Out:
# <class 'datetime.date'>

# %%
print(date_object)
# Out:
# 2016-01-08

# %%
#add the day of the week
date_object.strftime("%A %d %B %Y")
# Out:
# 'Friday 08 January 2016'

# %%
#apply the above to all elements in the xl_date array
dates = [None] * len(xl_date)
for i in range(len(xl_date)):
    datetime_date = xlrd.xldate_as_datetime(xl_date[i], 0)
    date_object = datetime_date.date()
    dates[i] = date_object.strftime("%A %d %B %Y")

# %%
len(dates)
# Out:
# 359392

# %%
len(xl_date)
# Out:
# 359392

# %%
print(dates[1:10])
# Out:
# ['Wednesday 06 January 2016', 'Saturday 02 January 2016', 'Thursday 07 January 2016', 'Sunday 03 January 2016', 'Thursday 07 January 2016', 'Sunday 03 January 2016', 'Thursday 07 January 2016', 'Tuesday 12 January 2016', 'Wednesday 06 January 2016']

# %%
#replace Excel date series with newly obtained dates
df2['Date of Travel'] = dates

# %%
df2.sample(5)
# Out:
#         Transaction ID              Date of Travel     Company         City  \
# 199804        10245274    Thursday 26 October 2017    Pink Cab     MIAMI FL
# 334024        10409379  Wednesday 14 November 2018  Yellow Cab   CHICAGO IL
# 103642        10126899   Saturday 17 December 2016  Yellow Cab  NEW YORK NY
# 27391         10034774        Saturday 21 May 2016  Yellow Cab   CHICAGO IL
# 8022          10010150   Saturday 13 February 2016  Yellow Cab  NEW YORK NY
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip
# 199804         12.48         133.56      138.5280        -4.9680    -0.037197
# 334024         31.20         428.59      408.0960        20.4940     0.047817
# 103642          4.52         121.97       58.5792        63.3908     0.519725
# 27391          15.21         287.13      215.3736        71.7564     0.249909
# 8022           29.70        1099.77      356.4000       743.3700     0.675932

# %%
#function to create months groups (all date groups will be necessary to investigate seasonality)
def months(date):
    if "January" in date:
        return "January"
    elif "February" in date:
        return "February"
    elif "March" in date:
        return "March"
    elif "April" in date:
        return "April"
    elif "May" in date:
        return "May"
    elif "June" in date:
        return "June"
    elif "July" in date:
        return "July"
    elif "August" in date:
        return "August"
    elif "September" in date:
        return "September"
    elif "October" in date:
        return "October"
    elif "November" in date:
        return "November"
    else:
        return "December"

df2['Month Of Travel'] = df2['Date of Travel'].apply(months)

# %%
df2.sample(5)
# Out:
#         Transaction ID             Date of Travel     Company            City  \
# 257245        10315412       Friday 30 March 2018  Yellow Cab      SEATTLE WA
# 241448        10295191     Monday 15 January 2018  Yellow Cab      CHICAGO IL
# 243093        10297192     Friday 26 January 2018  Yellow Cab     NEW YORK NY
# 247235        10302529  Thursday 15 February 2018  Yellow Cab        MIAMI FL
# 102966        10126223  Saturday 24 December 2016  Yellow Cab  LOS ANGELES CA
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 257245         22.89         382.76      280.1736       102.5864     0.268018
# 241448         31.03         453.79      413.3196        40.4704     0.089183
# 243093         27.36         930.90      338.1696       592.7304     0.636728
# 247235         10.78         221.75      147.4704        74.2796     0.334970
# 102966         30.38         514.12      390.0792       124.0408     0.241268
#
#        Month Of Travel
# 257245           March
# 241448         January
# 243093         January
# 247235        February
# 102966        December

# %%
#function to create groups based on the day of the week
def weekday(date):
    if "Monday" in date:
        return "Monday"
    elif "Tuesday" in date:
        return "Tuesday"
    elif "Wednesday" in date:
        return "Wednesday"
    elif "Thursday" in date:
        return "Thursday"
    elif "Friday" in date:
        return "Friday"
    elif "Saturday" in date:
        return "Saturday"
    else:
        return "Sunday"

df2['Week Day Of Travel'] = df2['Date of Travel'].apply(weekday)

# %%
df2.sample(5)
# Out:
#         Transaction ID            Date of Travel     Company            City  \
# 78325         10097016  Saturday 29 October 2016  Yellow Cab     NEW YORK NY
# 64065         10079945  Sunday 18 September 2016  Yellow Cab  LOS ANGELES CA
# 151414        10186627     Saturday 24 June 2017    Pink Cab   SACRAMENTO CA
# 287674        10353459    Wednesday 25 July 2018    Pink Cab    SAN DIEGO CA
# 177119        10218238  Friday 08 September 2017    Pink Cab      CHICAGO IL
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 78325          34.00         994.34       473.280        521.060     0.524026
# 64065          31.36         567.72       432.768        134.952     0.237709
# 151414          3.09          36.71        35.226          1.484     0.040425
# 287674         38.40         428.93       437.760         -8.830    -0.020586
# 177119         17.92         200.28       195.328          4.952     0.024725
#
#        Month Of Travel Week Day Of Travel
# 78325          October           Saturday
# 64065        September             Sunday
# 151414            June           Saturday
# 287674            July          Wednesday
# 177119       September             Friday

# %%
#function to create year groups
def year(date):
    if "2016" in date:
        return "2016"
    elif "2017" in date:
        return "2017"
    else:
        return "2018"

# %%
df2['Year Of Travel'] = df2['Date of Travel'].apply(year)

# %%
df2.sample(5)
# Out:
#         Transaction ID             Date of Travel     Company            City  \
# 194472        10238929    Tuesday 10 October 2017  Yellow Cab       DALLAS TX
# 291976        10358810     Tuesday 14 August 2018    Pink Cab  LOS ANGELES CA
# 58585         10073441  Tuesday 13 September 2016  Yellow Cab      CHICAGO IL
# 146651        10180640      Thursday 01 June 2017  Yellow Cab     NEW YORK NY
# 298382        10366501      Monday 27 August 2018  Yellow Cab     NEW YORK NY
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 194472          5.82         151.18       78.9192        72.2608     0.477979
# 291976         30.38         375.82      361.5220        14.2980     0.038045
# 58585          31.36         549.96      429.0048       120.9552     0.219935
# 146651         39.10        1157.27      525.5040       631.7660     0.545911
# 298382         29.76         700.04      428.5440       271.4960     0.387829
#
#        Month Of Travel Week Day Of Travel Year Of Travel
# 194472         October            Tuesday           2017
# 291976          August            Tuesday           2018
# 58585        September            Tuesday           2016
# 146651            June           Thursday           2017
# 298382          August             Monday           2018

# %%
print(df2.dtypes)
# Out:
# Transaction ID          int64
# Date of Travel         object
# Company                object
# City                   object
# KM Travelled          float64
# Price Charged         float64
# Cost of Trip          float64
# Earnings/Trip         float64
# Margin/Trip           float64
# Month Of Travel        object
# Week Day Of Travel     object
# Year Of Travel         object
# dtype: object

# %%
#function to create quarters
def quarter(date):
    if (("January" in date ) or ("February" in date) or ("March" in date)):
        return "Q1"
    elif (("April" in date) or ("May" in date ) or ("June" in date)):
        return "Q2"
    elif (("July" in date) or ("August" in date) or ("September" in date)):
        return "Q3"
    else:
        return "Q4"
    
df2['Travel Quarter'] = df2['Date of Travel'].apply(quarter)

# %%
df2.sample(5)
# Out:
#         Transaction ID            Date of Travel     Company           City  \
# 169032        10208465     Sunday 06 August 2017  Yellow Cab  WASHINGTON DC
# 324785        10398211    Sunday 28 October 2018  Yellow Cab    NEW YORK NY
# 204846        10251158   Friday 03 November 2017  Yellow Cab    NEW YORK NY
# 255352        10312801    Saturday 24 March 2018  Yellow Cab    NEW YORK NY
# 312253        10383206  Friday 28 September 2018  Yellow Cab    NEW YORK NY
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 169032         18.90         357.28      238.1400       119.1400     0.333464
# 324785         12.84         280.60      163.3248       117.2752     0.417944
# 204846         25.50         843.09      351.9000       491.1900     0.582607
# 255352         29.45         924.72      402.8760       521.8440     0.564326
# 312253         21.21         473.90      277.4268       196.4732     0.414588
#
#        Month Of Travel Week Day Of Travel Year Of Travel Travel Quarter
# 169032          August             Sunday           2017             Q3
# 324785         October             Sunday           2018             Q4
# 204846        November             Friday           2017             Q4
# 255352           March           Saturday           2018             Q1
# 312253       September             Friday           2018             Q3

# %%
#start creating master data by merging datasets on common columns; keep all values that don't match by adding NaN values (this is what the outer method of merging does)
df_res = df2.merge(df_city, on = 'City', how = 'outer')

# %%
print(df_res.sample(10))
# Out:
#         Transaction ID             Date of Travel     Company            City  \
# 178094      10057898.0      Saturday 30 July 2016  Yellow Cab     NEW YORK NY
# 152864      10392147.0     Friday 19 October 2018    Pink Cab  LOS ANGELES CA
# 93769       10397232.0     Friday 26 October 2018  Yellow Cab      CHICAGO IL
# 356658      10411411.0    Sunday 18 November 2018  Yellow Cab   WASHINGTON DC
# 186563      10093504.0  Wednesday 19 October 2016  Yellow Cab     NEW YORK NY
# 173631      10035020.0         Friday 20 May 2016  Yellow Cab     NEW YORK NY
# 123820      10128406.0  Thursday 29 December 2016    Pink Cab  LOS ANGELES CA
# 270005      10345705.0       Tuesday 03 July 2018    Pink Cab   ORANGE COUNTY
# 271612      10135877.0     Friday 06 January 2017  Yellow Cab      PHOENIX AZ
# 79824       10292215.0   Saturday 06 January 2018  Yellow Cab      CHICAGO IL
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 178094         37.37         960.95      461.8932       499.0568     0.519337
# 152864         16.24         194.54      173.7680        20.7720     0.106775
# 93769          14.04         213.67      185.3280        28.3420     0.132644
# 356658         23.75         309.48      330.6000       -21.1200    -0.068244
# 186563         18.24         363.60      240.7680       122.8320     0.337822
# 173631         40.00        1447.84      499.2000       948.6400     0.655211
# 123820         37.00         480.69      373.7000       106.9900     0.222576
# 270005         23.69         337.33      251.1140        86.2160     0.255584
# 271612          6.30         150.74       83.9160        66.8240     0.443306
# 79824          22.60         586.44      287.4720       298.9680     0.509802
#
#        Month Of Travel Week Day Of Travel Year Of Travel Travel Quarter  \
# 178094            July           Saturday           2016             Q3
# 152864         October             Friday           2018             Q4
# 93769          October             Friday           2018             Q4
# 356658        November             Sunday           2018             Q4
# 186563         October          Wednesday           2016             Q4
# 173631             May             Friday           2016             Q2
# 123820        December           Thursday           2016             Q4
# 270005            July            Tuesday           2018             Q3
# 271612         January             Friday           2017             Q1
# 79824          January           Saturday           2018             Q1
#
#         Population   Users
# 178094     8405837  302149
# 152864     1595037  144132
# 93769      1955130  164468
# 356658      418859  127001
# 186563     8405837  302149
# 173631     8405837  302149
# 123820     1595037  144132
# 270005     1030185   12994
# 271612      943999    6133
# 79824      1955130  164468

# %%
df_res = df_res.merge(df_transaction, on = 'Transaction ID', how = 'outer')

# %%
print(df_res.sample(10))
# Out:
#         Transaction ID             Date of Travel     Company            City  \
# 106090      10037085.0         Sunday 22 May 2016  Yellow Cab       DENVER CO
# 34756       10324802.0         Monday 07 May 2018  Yellow Cab       BOSTON MA
# 137594      10250931.0     Monday 30 October 2017  Yellow Cab  LOS ANGELES CA
# 169332      10012008.0    Monday 22 February 2016  Yellow Cab     NEW YORK NY
# 68878       10203435.0    Saturday 05 August 2017  Yellow Cab      CHICAGO IL
# 239636      10323471.0       Monday 23 April 2018  Yellow Cab     NEW YORK NY
# 360300      10004029.0                        NaN         NaN             NaN
# 37584       10368661.0      Friday 31 August 2018  Yellow Cab       BOSTON MA
# 61589       10150148.0       Sunday 05 March 2017  Yellow Cab      CHICAGO IL
# 199414      10144572.0  Thursday 09 February 2017  Yellow Cab     NEW YORK NY
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 106090         24.15         605.93      339.0660       266.8640     0.440421
# 34756          43.32         669.63      577.0224        92.6076     0.138297
# 137594          3.42          53.42       43.5024         9.9176     0.185653
# 169332         14.98         482.21      206.7240       275.4860     0.571299
# 68878          21.78         231.58      300.5640       -68.9840    -0.297884
# 239636         19.55         535.01      260.4060       274.6040     0.513269
# 360300           NaN            NaN           NaN            NaN          NaN
# 37584          22.31         373.23      299.8464        73.3836     0.196618
# 61589           7.49         107.88      106.0584         1.8216     0.016885
# 199414         17.17         457.34      232.8252       224.5148     0.490914
#
#        Month Of Travel Week Day Of Travel Year Of Travel Travel Quarter  \
# 106090             May             Sunday           2016             Q2
# 34756              May             Monday           2018             Q2
# 137594         October             Monday           2017             Q4
# 169332        February             Monday           2016             Q1
# 68878           August           Saturday           2017             Q3
# 239636           April             Monday           2018             Q2
# 360300             NaN                NaN            NaN            NaN
# 37584           August             Friday           2018             Q3
# 61589            March             Sunday           2017             Q1
# 199414        February           Thursday           2017             Q1
#
#         Population     Users  Customer ID Payment_Mode
# 106090    754233.0   12421.0      32015.0         Cash
# 34756     248968.0   80021.0      59224.0         Cash
# 137594   1595037.0  144132.0       6396.0         Card
# 169332   8405837.0  302149.0       1866.0         Card
# 68878    1955130.0  164468.0       5385.0         Card
# 239636   8405837.0  302149.0       2642.0         Cash
# 360300         NaN       NaN      44316.0         Cash
# 37584     248968.0   80021.0      57356.0         Cash
# 61589    1955130.0  164468.0       4168.0         Card
# 199414   8405837.0  302149.0       2351.0         Cash

# %%
df_res = df_res.merge(df_customer, on = 'Customer ID', how = 'outer')

# %%
print(df_res.sample(10))
# Out:
#         Transaction ID             Date of Travel     Company            City  \
# 392697      10140006.0                        NaN         NaN             NaN
# 229174      10100811.0  Saturday 05 November 2016  Yellow Cab     NEW YORK NY
# 226167      10439005.0   Thursday 04 January 2018  Yellow Cab     NEW YORK NY
# 285116      10095587.0   Saturday 29 October 2016    Pink Cab    SAN DIEGO CA
# 386486      10062153.0                        NaN         NaN             NaN
# 16244       10417161.0    Monday 03 December 2018  Yellow Cab       BOSTON MA
# 121328      10187542.0        Friday 23 June 2017  Yellow Cab  LOS ANGELES CA
# 428582      10266876.0                        NaN         NaN             NaN
# 344169      10119814.0  Thursday 08 December 2016  Yellow Cab   WASHINGTON DC
# 379304      10293282.0                        NaN         NaN             NaN
#
#         KM Travelled  Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip  \
# 392697           NaN            NaN           NaN            NaN          NaN
# 229174          9.81         232.80       123.606        109.194     0.469046
# 226167         19.60         438.19       282.240        155.950     0.355896
# 285116          8.64         111.01        92.448         18.562     0.167210
# 386486           NaN            NaN           NaN            NaN          NaN
# 16244          16.20         241.82       227.448         14.372     0.059433
# 121328         30.30         491.27       425.412         65.858     0.134057
# 428582           NaN            NaN           NaN            NaN          NaN
# 344169          7.70          97.77       103.488         -5.718    -0.058484
# 379304           NaN            NaN           NaN            NaN          NaN
#
#        Month Of Travel  ... Travel Quarter Population     Users  Customer ID  \
# 392697             NaN  ...            NaN        NaN       NaN      44875.0
# 229174        November  ...             Q4  8405837.0  302149.0        309.0
# 226167         January  ...             Q1  8405837.0  302149.0       2086.0
# 285116         October  ...             Q4   959307.0   69995.0      19808.0
# 386486             NaN  ...            NaN        NaN       NaN      44286.0
# 16244         December  ...             Q4   248968.0   80021.0      58922.0
# 121328            June  ...             Q2  1595037.0  144132.0       7781.0
# 428582             NaN  ...            NaN        NaN       NaN      42469.0
# 344169        December  ...             Q4   418859.0  127001.0      51052.0
# 379304             NaN  ...            NaN        NaN       NaN      42283.0
#
#         Payment_Mode  Gender   Age Income (USD/Month)  \
# 392697          Card  Female  36.0            18473.0
# 229174          Cash    Male  20.0            23727.0
# 226167          Card    Male  40.0             9785.0
# 285116          Cash    Male  34.0            19533.0
# 386486          Card    Male  29.0             7969.0
# 16244           Cash    Male  55.0            16044.0
# 121328          Cash  Female  37.0            15829.0
# 428582          Card  Female  37.0            13153.0
# 344169          Cash    Male  34.0            23381.0
# 379304          Card    Male  21.0            24716.0
#
#                         Age Category  Income Category
# 392697               35-45 years old      15000-25000
# 229174  Young adults 18-25 years old      15000-25000
# 226167               35-45 years old       5000-15000
# 285116               25-35 years old      15000-25000
# 386486               25-35 years old       5000-15000
# 16244                45-65 years old      15000-25000
# 121328               35-45 years old      15000-25000
# 428582               35-45 years old       5000-15000
# 344169               25-35 years old      15000-25000
# 379304  Young adults 18-25 years old      15000-25000
#
# [10 rows x 22 columns]

# %%
df_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440099 entries, 0 to 440098
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      440098 non-null  float64
#  1   Date of Travel      359392 non-null  object
#  2   Company             359392 non-null  object
#  3   City                359393 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Earnings/Trip       359392 non-null  float64
#  8   Margin/Trip         359392 non-null  float64
#  9   Month Of Travel     359392 non-null  object
#  10  Week Day Of Travel  359392 non-null  object
#  11  Year Of Travel      359392 non-null  object
#  12  Travel Quarter      359392 non-null  object
#  13  Population          359393 non-null  float64
#  14  Users               359393 non-null  float64
#  15  Customer ID         440098 non-null  float64
#  16  Payment_Mode        440098 non-null  object
#  17  Gender              440098 non-null  object
#  18  Age                 440098 non-null  float64
#  19  Income (USD/Month)  440098 non-null  float64
#  20  Age Category        440098 non-null  object
#  21  Income Category     440098 non-null  object
# dtypes: float64(11), object(11)
# memory usage: 77.2+ MB

# %%
#adding a rate of cab users/city to both the City dataset and the dataset that will be turned into the master, although this remains unused for now
df_res['Rate of Use/City']=df_res['Users']/df_res['Population']

# %%
df_city['Rate of Use/City']=df_city['Users']/df_city['Population']

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              20 non-null     object
#  1   Population        20 non-null     int64
#  2   Users             20 non-null     int64
#  3   Rate of Use/City  20 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 768.0+ bytes

# %%
print(df_city.sample(10))
# Out:
#               City  Population   Users  Rate of Use/City
# 1       CHICAGO IL     1955130  164468          0.084121
# 19       BOSTON MA      248968   80021          0.321411
# 17   WASHINGTON DC      418859  127001          0.303207
# 18    NASHVILLE TN      327225    9270          0.028329
# 2   LOS ANGELES CA     1595037  144132          0.090363
# 5    ORANGE COUNTY     1030185   12994          0.012613
# 9       ATLANTA GA      814885   24701          0.030312
# 4   SILICON VALLEY     1177609   27247          0.023138
# 12      SEATTLE WA      671238   25063          0.037338
# 0      NEW YORK NY     8405837  302149          0.035945

# %%
#creating master data by only selecting certain categories: most important are demographic data (age, gender, income), earnings and margin, seasonality (with different types) and length of the journey (km).
master_data = df_res[['Company','Transaction ID', 'Customer ID', 'Payment_Mode', 'Gender', 'Age Category', 'Income Category', 'Year Of Travel', 'Travel Quarter', 'Month Of Travel', 'Week Day Of Travel', 'City', 'Rate of Use/City','KM Travelled', 'Price Charged', 'Cost of Trip', 'Earnings/Trip', 'Margin/Trip']]

# %%
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440099 entries, 0 to 440098
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Company             359392 non-null  object
#  1   Transaction ID      440098 non-null  float64
#  2   Customer ID         440098 non-null  float64
#  3   Payment_Mode        440098 non-null  object
#  4   Gender              440098 non-null  object
#  5   Age Category        440098 non-null  object
#  6   Income Category     440098 non-null  object
#  7   Year Of Travel      359392 non-null  object
#  8   Travel Quarter      359392 non-null  object
#  9   Month Of Travel     359392 non-null  object
#  10  Week Day Of Travel  359392 non-null  object
#  11  City                359393 non-null  object
#  12  Rate of Use/City    359393 non-null  float64
#  13  KM Travelled        359392 non-null  float64
#  14  Price Charged       359392 non-null  float64
#  15  Cost of Trip        359392 non-null  float64
#  16  Earnings/Trip       359392 non-null  float64
#  17  Margin/Trip         359392 non-null  float64
# dtypes: float64(8), object(10)
# memory usage: 63.8+ MB

# %%
master_data.sample(5)
# Out:
#            Company  Transaction ID  Customer ID Payment_Mode  Gender  \
# 310488    Pink Cab      10194525.0      12892.0         Cash  Female
# 280281    Pink Cab      10151720.0      19005.0         Card  Female
# 255823  Yellow Cab      10058291.0       2629.0         Card  Female
# 30994   Yellow Cab      10034465.0      59263.0         Card  Female
# 187135  Yellow Cab      10282901.0       1506.0         Cash    Male
#
#                         Age Category Income Category Year Of Travel  \
# 310488  Young adults 18-25 years old     15000-25000           2017
# 280281               35-45 years old     15000-25000           2017
# 255823  Young adults 18-25 years old     15000-25000           2016
# 30994                25-35 years old       3000-5000           2016
# 187135               35-45 years old       3000-5000           2017
#
#        Travel Quarter Month Of Travel Week Day Of Travel            City  \
# 310488             Q3            July            Tuesday  SILICON VALLEY
# 280281             Q1           March             Friday    SAN DIEGO CA
# 255823             Q3            July           Saturday     NEW YORK NY
# 30994              Q2             May             Sunday       BOSTON MA
# 187135             Q4        December             Sunday     NEW YORK NY
#
#         Rate of Use/City  KM Travelled  Price Charged  Cost of Trip  \
# 310488          0.023138         14.40         208.08      169.9200
# 280281          0.072964         35.36         686.29      353.6000
# 255823          0.035945         13.91         478.31      188.6196
# 30994           0.321411         38.00         543.12      515.2800
# 187135          0.035945         24.99         671.90      347.8608
#
#         Earnings/Trip  Margin/Trip
# 310488        38.1600     0.183391
# 280281       332.6900     0.484766
# 255823       289.6904     0.605654
# 30994         27.8400     0.051259
# 187135       324.0392     0.482273

# %%
#Starting to look at average earnings/margin per company and other descriptive analyses
#Hypothesis 1: Yellow Cab is more profitable than Pink Cab
metrics = master_data.groupby(['Company'])[['Price Charged', 'Cost of Trip']].mean()

# %%
print(metrics)
# Out:
#             Price Charged  Cost of Trip
# Company
# Pink Cab       310.800856    248.148682
# Yellow Cab     458.181990    297.922004

# %%
Median_usd = ['Price Charged', 'Cost of Trip']

# %%
pink_cab = metrics[metrics.index == 'Pink Cab'].values
pink_cab = pink_cab.reshape(-1)
print(pink_cab)
# Out:
# [310.8009 248.1487]

# %%
yellow_cab = metrics[metrics.index == 'Yellow Cab'].values
yellow_cab = yellow_cab.reshape(-1)
print(yellow_cab)
# Out:
# [458.1820 297.9220]

# %%
x = np.arange(2)

# %%
width = 0.3

# %%
fig, ax = plt.subplots()
ax.bar(x - 0.3/2, pink_cab, width, label = "Pink Cab", color = 'pink')
ax.bar(x + 0.3/2, yellow_cab, width, label = "Yellow Cab", color = 'yellow')
plt.xticks(x, Median_usd)
plt.ylabel('USD Total')
plt.title('Price Charged vs Cost of Trip per Company')
plt.legend()
plt.show()

# %% [markdown]
# Yellow Cab charged higher prices for their trips but their trips also costed more (although the ratios between the two companies are not the same across the two measurements); it would be interesting to see why that is - does Yellow Cab take relatively longer journeys compared to Pink Cab? How does this affect the profit vs the revenue?

# %%
margins = master_data.groupby(['Company'])[['Earnings/Trip','Margin/Trip']].mean()

# %%
print(margins)
# Out:
#             Earnings/Trip  Margin/Trip
# Company
# Pink Cab        62.652174     0.173808
# Yellow Cab     160.259986     0.301345

# %%
margins = margins.values

# %%
print(margins)
# Out:
# [[62.6522 0.1738]
#  [160.2600 0.3013]]

# %%
print(margins[0,:])
# Out:
# [62.6522 0.1738]

# %%
pink_cabm = margins[0,:]
yellow_cabm = margins[1,:]

# %%
print(pink_cabm)
print(yellow_cabm)
print('The earnings/trip of yellow cab are ', round(yellow_cabm[0]/pink_cabm[0],2), 'times greater than that of Pink Cab')
print('The margin/trip of yellow cab is ', round(yellow_cabm[1]/pink_cabm[1],2), 'times greater than that of Pink Cab')
#multiply relative margins by 100 to be in the same scale as margin
#pink_cabm[1] = pink_cabm[1]*100
#yellow_cabm[1] = yellow_cabm[1]*100
# Out:
# [62.6522 0.1738]
# [160.2600 0.3013]
# The earnings/trip of yellow cab are  2.56 times greater than that of Pink Cab
# The margin/trip of yellow cab is  1.73 times greater than that of Pink Cab

# %%
Company = ['Pink Cab', 'Yellow Cab']
fig, ax = plt.subplots()
ax.bar(Company, margins[:,0], width, color = ['pink', 'yellow'])
plt.ylabel('Average Earnings (USD)')
plt.title('Earnings/Trip per Company')
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(Company, margins[:,1]*100, width, color = ['pink', 'yellow'])
plt.ylabel('Average Margin %')
plt.title('Margin/Trip per Company')
plt.show()

# %% [markdown]
# Yellow Cab has more earnings and a better margin than Pink Cab, although the margin ratio is smaller between the two companies compared to the earnings.

# %%
#Let's see if Yellow Cab also dominates through number of trips compared to Pink Cab, we will
#just count the rows in master_data/company
master_data.groupby(['Company']).count()
# Out:
#             Transaction ID  Customer ID  Payment_Mode  Gender  Age Category  \
# Company
# Pink Cab             84711        84711         84711   84711         84711
# Yellow Cab          274681       274681        274681  274681        274681
#
#             Income Category  Year Of Travel  Travel Quarter  Month Of Travel  \
# Company
# Pink Cab              84711           84711           84711            84711
# Yellow Cab           274681          274681          274681           274681
#
#             Week Day Of Travel    City  Rate of Use/City  KM Travelled  \
# Company
# Pink Cab                 84711   84711             84711         84711
# Yellow Cab              274681  274681            274681        274681
#
#             Price Charged  Cost of Trip  Earnings/Trip  Margin/Trip
# Company
# Pink Cab            84711         84711          84711        84711
# Yellow Cab         274681        274681         274681       274681

# %%
#In the existing dataset, Yellow Cab figures with more trips (274681) than Pink Cab (84711)

# %%
#Why is Yellow Cab more profitable?
#Hypothesis 2: They make longer trips 
sns.histplot(x = 'KM Travelled', hue = 'Company', bins = 100, data = df, palette = ['pink', 'yellow'])
plt.title('Number of Trips per Total KM Travelled')
plt.show()

# %%
#The distributions of trip distances per company have similar shapes for both companies
#(they are proportional), so we cannot say that one company makes proportionally more or 
#less long trips than the other (we already know that the total count of trips is higher 
#for Yellow Cab)

# %%
#Hypothesis 3: They charge more per km - we don't know, but may be inferred from correlation between distance travelled
#and earnings 
sns.scatterplot(x='KM Travelled', y='Earnings/Trip', data=master_data, hue='Company', palette = ['pink', 'yellow'])
plt.title('Relationship between Distance of Trip and Earnings/Trip')
plt.show()
#sns.scatterplot(x='KM Travelled', y='Earnings/Trip', data=master_data.sample(1000), hue='Company', palette = ['pink', 'yellow'])

# %%
#sns.scatterplot(x='KM Travelled', y='Margin/Trip', data=master_data, hue='Company', palette = ['pink', 'yellow'])

# %% [markdown]
# Yellow Cab has a stronger positive trend between the km travelled and earnings/trip (aside from the total number of trips which is greater for Yellow Cab) than Pink Cab. Pink Cab also makes noticeably more negative earnings/trip, which indicates potential issues with the business model. Given Pink Cab's losses, it cannot be inferred whether Yellow Cab charges more per km.

# %%
#Let's see how demographics affect each company's profitability, whether one company caters for a particular demographic group, etc
#Hypothesis 4: Demographics affect earnings/number of trips differently for each company
age_data = master_data.groupby(['Age Category', 'Company'])['Customer ID'].aggregate('mean')
income_data = master_data.groupby(['Income Category', 'Company'])['Customer ID'].aggregate('mean')
gender_data = master_data.groupby(['Gender', 'Company'])['Customer ID'].aggregate('mean')

# %%
print(age_data, '\n')
print(income_data, '\n')
print(gender_data)
# Out:
# Age Category                  Company
# 25-35 years old               Pink Cab      18773.103354
#                               Yellow Cab    19933.946787
# 35-45 years old               Pink Cab      18647.882252
#                               Yellow Cab    19711.660205
# 45-65 years old               Pink Cab      18023.126686
#                               Yellow Cab    18863.463139
# Seniors >65 years old         Pink Cab      19759.925700
#                               Yellow Cab    21351.217357
# Young adults 18-25 years old  Pink Cab      18026.747488
#                               Yellow Cab    18887.963071
# Name: Customer ID, dtype: float64
#
# Income Category  Company
# 15000-25000      Pink Cab      18121.524544
#                  Yellow Cab    19042.426318
# 2000-3000        Pink Cab      18215.468835
#                  Yellow Cab    18991.205392
# 3000-5000        Pink Cab      18980.469670
#                  Yellow Cab    20606.805553
# 5000-15000       Pink Cab      18567.758275
#                  Yellow Cab    19699.261548
# >25000           Pink Cab      18706.974497
#                  Yellow Cab    19110.009958
# Name: Customer ID, dtype: float64
#
# Gender  Company
# Female  Pink Cab      19168.565795
#         Yellow Cab    20327.327879
# Male    Pink Cab      17830.608329
#         Yellow Cab    18772.007329
# Name: Customer ID, dtype: float64

# %%
#plot total number of customers for each demographic first 
age_data\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], xlabel = '',
      ylabel = 'Total Number of Customers', title = 'Customers per Age Category per Company')
# Out:
# <AxesSubplot:title={'center':'Customers per Age Category per Company'}, ylabel='Total Number of Customers'>

# %% [markdown]
# While, overall there are slightly more Yellow cab users in each agroup, and more senior customers for each of the two companies, the differences between companies and age groups are minimal.

# %%
income_data\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], xlabel = 'Income per Month (USD)', 
      ylabel = 'Total Number of Customers', title = 'Customers per Income Category per Company')
# Out:
# <AxesSubplot:title={'center':'Customers per Income Category per Company'}, xlabel='Income per Month (USD)', ylabel='Total Number of Customers'>

# %% [markdown]
# Similarly, the income category/company differences between all subgroups are minimal.

# %%
gender_data\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 0, color = ['pink', 'yellow'], xlabel = '',
      ylabel = 'Total Number of Customers', title = 'Customers per Gender Group per Company')
# Out:
# <AxesSubplot:title={'center':'Customers per Gender Group per Company'}, ylabel='Total Number of Customers'>

# %% [markdown]
# There are no differences between the two companies in the number of customers split by gender - customer total is similar for the two companies, as well as demographic distribution, which is an important point.

# %%
master_data.groupby(['Age Category', 'Company'])['Age Category'].count()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], xlabel ='',
      ylabel = 'Total Number of Trips', title = 'Total Trips per Age Category per Company')
# Out:
# <AxesSubplot:title={'center':'Total Trips per Age Category per Company'}, ylabel='Total Number of Trips'>

# %% [markdown]
# Even though there is no difference between number of customers between the age groups, seniors seem to make the least number of trips, while people aged between 25-35 years old make the most trips (with the proportional observed differences between the two companies).

# %%
master_data.groupby(['Income Category', 'Company'])['Income Category'].count()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], xlabel = 'Income per Month (USD)',
      ylabel = 'Total Number of Trips', title = 'Total Trips per Income Category per Company')
# Out:
# <AxesSubplot:title={'center':'Total Trips per Income Category per Company'}, xlabel='Income per Month (USD)', ylabel='Total Number of Trips'>

# %% [markdown]
# Similarly, people with incomes over 5000 USD per month seem to use both companies more, but the trends between the two companies are the same (the total number of trips being greater for Yellow Cab than for Pink Cab).

# %%
master_data.groupby(['Gender', 'Company'])['Gender'].count()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 0, color = ['pink', 'yellow'], xlabel = '',
      ylabel = 'Total Number of Trips', title = 'Total Trips per Gender per Company')
# Out:
# <AxesSubplot:title={'center':'Total Trips per Gender per Company'}, ylabel='Total Number of Trips'>

# %% [markdown]
# Again the total number of trips is higher for Yellow Cab, but there is no difference between the total trips per company between the genders.

# %%
master_data.groupby(['Age Category', 'Company'])['Earnings/Trip'].mean()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], xlabel = '',
      ylabel = 'Earnings per Trip (USD)', title = 'Mean Earnings per Age Category per Company')
# Out:
# <AxesSubplot:title={'center':'Mean Earnings per Age Category per Company'}, ylabel='Earnings per Trip (USD)'>

# %%
master_data.groupby(['Income Category', 'Company'])['Earnings/Trip'].mean()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], xlabel = 'Income per Month (USD)',
      ylabel = 'Earnings/Trip (USD)', title = 'Mean Earnings per Income Category per Company')
# Out:
# <AxesSubplot:title={'center':'Mean Earnings per Income Category per Company'}, xlabel='Income per Month (USD)', ylabel='Earnings/Trip (USD)'>

# %%
master_data.groupby(['Gender', 'Company'])['Earnings/Trip'].mean()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 0, color = ['pink', 'yellow'], xlabel = '',
      ylabel = 'Earnings/Trip (USD)', title = 'Mean Earnings per Gender Category per Company')
# Out:
# <AxesSubplot:title={'center':'Mean Earnings per Gender Category per Company'}, ylabel='Earnings/Trip (USD)'>

# %% [markdown]
# Similarly, no demographic group contributes more to either of the two companies' profit.

# %%
#Let's now look at city data (total number of trips and margin/trip) for each company 
#Hypothesis 5: there will be different trends of use across cities depending on each company
master_data.groupby(['City', 'Company'])['Margin/Trip'].mean()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', color = ['pink', 'yellow'], xlabel = '', 
      ylabel = 'Average Margin/Trip', title = 'Mean Margin/Trip per City per Company')
# Out:
# <AxesSubplot:title={'center':'Mean Margin/Trip per City per Company'}, ylabel='Average Margin/Trip'>

# %%
master_data.groupby(['City', 'Company'])['City'].count()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', color = ['pink', 'yellow'], xlabel = '',
      ylabel = 'Total Number of Trips', title = 'Total Number of trips per City per Company')
# Out:
# <AxesSubplot:title={'center':'Total Number of trips per City per Company'}, ylabel='Total Number of Trips'>

# %%
df_city.plot(kind = 'bar', x = 'City', y = 'Population', xlabel = '',
             ylabel = '# of Residents', title='Total Population of each City', legend = False)
# Out:
# <AxesSubplot:title={'center':'Total Population of each City'}, ylabel='# of Residents'>

# %%
df_city.groupby(['City'])['Rate of Use/City'].mean()\
.sort_index()\
.plot(kind = 'bar', xlabel = '', ylabel = 'Rate of Use/City', title = 'Mean Rate of Cab Use/City')
# Out:
# <AxesSubplot:title={'center':'Mean Rate of Cab Use/City'}, ylabel='Rate of Use/City'>

# %% [markdown]
# Yellow Cab succeeds at having a larger profit and presence in larger cities, as well as in cities where Pink Cab does very poorly (such as New York, Chicago, and Boston). On the contrary, Pink Cab does not do as good in larger cities, except perhaps San Diego and Los Angeles. It would be interesting to investigate city effects further - perhaps per region/state, and investigate climate influences (combined with seasonality).

# %%
#Investigate year and seasonality (quarter, month, day of week) effects of each company
#Hypothesis 6: there will be different effects of seasonality on the margin/trip of each company
#Year
master_data.groupby(['Year Of Travel', 'Company'])['Margin/Trip'].mean()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 0, color = ['pink', 'yellow'], ylabel = 'Margin/Trip ', title = 'Mean Margin/Trip 2016-2018 for each Company')
plt.legend(loc = 3)

# %%
master_data.groupby(['Travel Quarter', 'Company'])['Margin/Trip'].mean()\
.sort_index()\
.unstack()\
.plot(kind = 'bar', rot = 0, color = ['pink', 'yellow'], ylabel = 'Margin/Trip ', title = 'Mean Margin/Trip per Quarter for each Company')
# Out:
# <AxesSubplot:title={'center':'Mean Margin/Trip per Quarter for each Company'}, xlabel='Travel Quarter', ylabel='Margin/Trip '>

# %%
master_data.groupby(['Month Of Travel', 'Company'])['Earnings/Trip'].mean()\
.sort_index()\
.unstack()\
.reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], ylabel = 'Margin/Trip ', title = 'Mean Margin/Trip per month for each Company')
# Out:
# <AxesSubplot:title={'center':'Mean Margin/Trip per month for each Company'}, xlabel='Month Of Travel', ylabel='Margin/Trip '>

# %%
master_data.groupby(['Week Day Of Travel', 'Company'])['Margin/Trip'].mean()\
.sort_index()\
.unstack()\
.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])\
.plot(kind = 'bar', rot = 45, color = ['pink', 'yellow'], ylabel = 'Margin/Trip ', title = 'Mean Margin/Trip per Weekday for each Company')
# Out:
# <AxesSubplot:title={'center':'Mean Margin/Trip per Weekday for each Company'}, xlabel='Week Day Of Travel', ylabel='Margin/Trip '>

# %% [markdown]
# Seasonality effects are the same for both companies in terms of year and days of the week, but they are different in terms of quarter and months. Yellow Cab has higher margins in the first two quarters, as well as in warmer months such as May (although there is an increase in the colder months of January and February for both companies). However, Pink Cab shows margin peaks in December and quarters 1 and 4, but these drop in Q3 and the months of May, June and July. It would be interesting to investigate how and why weather or climate aspects may influence these trends.

# %% [markdown]
# City and Seasonality seem to offer differences in predictions for each company's success, measured in margin/trip (or earnings/trip). They could potentially be used as factors in a linear regression algorithm to predict future margins - although interactions between the two factors should also be investigates. More information about each company's business model would also be useful.
